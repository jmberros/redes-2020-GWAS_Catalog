# %% [markdown]
# Acá generamos el dataframe de base en el que se basará la red.
#
# Descarga de los datos: https://www.ebi.ac.uk/gwas/docs/file-downloads, "All associations v1.0.2 - with added ontology".
#
# Me quedo sólo con algunas columnas del dataset de asociaciones, les pongo nombres amigables y
# les asigno una categoría fenotípica a cada carácter (éstas vienen de un segundo archivo).
#
# Escribo el resultado a un nuevo dataset para basar todo el trabajo en ese.

# %%
# %run imports.py

# %% [markdown]
# ## Carga y limpieza del dataset

# %% [markdown]
# ### Asociaciones variante-fenotipo

# %%
path = f"{data_dir}/gwas_catalog_v1.0.2-associations_e98_r2020-05-03.tsv.gz"
df_assoc_full = pd.read_table(path, low_memory=False)
print("Columnas disponibles: ", " | ".join(df_assoc_full.columns))

columnas = {
    "DISEASE/TRAIT": "fenotipo",
    "CHR_ID": "crom",
    "CHR_POS": "pos",
    "REPORTED GENE(S)": "genes_reportados",
    "MAPPED_GENE": "genes_mapeados",
    "STRONGEST SNP-RISK ALLELE": "alelo_riesgo",
    "CONTEXT": "contexto",
    "INTERGENIC": "es_intergenico",
    "RISK ALLELE FREQUENCY": "frec_alelo_riesgo",
    "P-VALUE": "p_value",
    "OR or BETA": "OR_or_beta",
    "95% CI (TEXT)": "conf_int_95"
}
df_assoc = df_assoc_full[columnas].rename(columns=columnas)
df_assoc
# Out:
# Columnas disponibles:  DATE ADDED TO CATALOG | PUBMEDID | FIRST AUTHOR | DATE | JOURNAL | LINK | STUDY | DISEASE/TRAIT | INITIAL SAMPLE SIZE | REPLICATION SAMPLE SIZE | REGION | CHR_ID | CHR_POS | REPORTED GENE(S) | MAPPED_GENE | UPSTREAM_GENE_ID | DOWNSTREAM_GENE_ID | SNP_GENE_IDS | UPSTREAM_GENE_DISTANCE | DOWNSTREAM_GENE_DISTANCE | STRONGEST SNP-RISK ALLELE | SNPS | MERGED | SNP_ID_CURRENT | CONTEXT | INTERGENIC | RISK ALLELE FREQUENCY | P-VALUE | PVALUE_MLOG | P-VALUE (TEXT) | OR or BETA | 95% CI (TEXT) | PLATFORM [SNPS PASSING QC] | CNV | MAPPED_TRAIT | MAPPED_TRAIT_URI | STUDY ACCESSION | GENOTYPING TECHNOLOGY
#                    fenotipo crom        pos                  genes_reportados  \
# 0           Crohn's disease   10    6060049                             IL2RA
# 1           Crohn's disease   16   28479196     IL27, SH2B1, EIF3C, LAT, CD19
# 2           Crohn's disease    1   67240275                             IL23R
# 3           Crohn's disease    2  102437989  IL12RL2, IL18R1, IL1RL1, IL18RAP
# 4           Crohn's disease    5  159360377                             IL12B
# ...                     ...  ...        ...                               ...
# 185719  Lung adenocarcinoma    6   31652743                        APOM, BAT3
# 185720  Lung adenocarcinoma   15   78601997                    CHRNA5, CHRNA3
# 185721  Lung adenocarcinoma    5    1342599                           CLPTM1L
# 185722  Lung adenocarcinoma    6   28808340                         TRNAA-UGC
# 185723  Lung adenocarcinoma    5    1286401                              TERT
#
#                                   genes_mapeados  alelo_riesgo  \
# 0                                          IL2RA  rs12722489-C
# 1                               CLN3, AC138894.1    rs151181-G
# 2                                          IL23R  rs11209026-G
# 3                                        IL18RAP   rs2058660-G
# 4                                     AC008691.1   rs6556412-A
# ...                                          ...           ...
# 185719  APOM, APOM, APOM, APOM, APOM, APOM, APOM   rs3117582-C
# 185720                                    CHRNA3   rs1051730-T
# 185721                                   CLPTM1L     rs31489-C
# 185722                      NOP56P1 - AL662890.1   rs4324798-A
# 185723                                      TERT   rs2736100-G
#
#                    contexto  es_intergenico frec_alelo_riesgo p_value  \
# 0            intron_variant             0.0             0.852    3E-9
# 1            intron_variant             0.0             0.386   2E-11
# 2          missense_variant             0.0             0.932   1E-64
# 3            intron_variant             0.0             0.231   2E-12
# 4            intron_variant             0.0             0.332   5E-14
# ...                     ...             ...               ...     ...
# 185719       intron_variant             0.0              0.10   5E-12
# 185720   synonymous_variant             0.0              0.35   2E-51
# 185721       intron_variant             0.0              0.59   2E-10
# 185722   intergenic_variant             1.0              0.09    2E-8
# 185723  3_prime_UTR_variant             0.0              0.50   2E-10
#
#         OR_or_beta  conf_int_95
# 0             1.11  [1.05-1.16]
# 1             1.07  [1.03-1.12]
# 2             2.66  [2.36-3.00]
# 3             1.19  [1.14-1.26]
# 4             1.18  [1.13-1.24]
# ...            ...          ...
# 185719        1.22  [1.15-1.29]
# 185720        1.31  [1.27-1.36]
# 185721        1.12  [1.09-1.16]
# 185722        1.16  [1.09-1.24]
# 185723        1.12  [1.08-1.16]
#
# [185724 rows x 12 columns]

# %%
from more_itertools import unique_everseen

def eliminar_items_repetidos(items_str, sep):
    if pd.isna(items_str):
        return
    
    items_unicos = unique_everseen(items_str.split(sep))
    return " | ".join(item.strip() for item in items_unicos)

# Hay valores como "APOM, APOM, APOM" en los genes, también "GEN1; GEN1". Limpiamos
# y unificamos el separador como " | ":

for sep in [",", ";"]:
    df_assoc["genes_mapeados"] = df_assoc.genes_mapeados.apply(eliminar_items_repetidos, sep=sep)
    df_assoc["genes_reportados"] = df_assoc.genes_reportados.apply(eliminar_items_repetidos, sep=sep)

# %%
d = {"foo": 2, "bar": 4, "baz": 1}
# max(d, key=itemgetter(1))
pd.Series(d).idxmax()
# Out:
# 'bar'

# %%
from more_itertools import flatten
from collections import Counter

genes_mapeados_por_alelo = df_assoc.genes_mapeados.dropna().apply(lambda genes_str: genes_str.split(" | "))
genes_mapeados_frecuencia = pd.Series(flatten(genes_mapeados_por_alelo)).value_counts()
genes_ordenados_por_frecuencia = genes_mapeados_frecuencia.index

genes_mapeados_frecuencia["SARM1"]
# Out:
# 1314

# %%
def elegir_un_gen(genes_str, sep):
    """Quita genes que se ven poco interesantes por razones variadas y de los restantes
       elige el más frecuente del dataset. Si hay empates elige el primero."""
    if pd.isna(genes_str):
        return
   
    genes = genes_str.split(sep)
    genes_interesantes = [
        gen for gen in genes if
        "." not in gen and # probablemente ids no interesantes
        " - " not in gen and # alelo intergénico reportado entre GEN1 - GEN2
        "-" not in gen and # genes antisense tipo FOOBAR-AS1
        "orf" not in gen # ORFs sin función identificada
    ]
    
    if not genes_interesantes:
        return
    
    frecuencias_por_gen = pd.Series({gen: genes_mapeados_frecuencia[gen]
                                     for gen in genes_interesantes}, dtype=int)
    return frecuencias_por_gen.idxmax()
    

df_assoc["gen_mapeado_elegido"] = df_assoc.genes_mapeados.progress_apply(elegir_un_gen, sep=" | ")
# Out:
# 100%|██████████| 185724/185724 [01:03<00:00, 2912.22it/s]

# %%
df_assoc
# Out:
#                    fenotipo crom        pos  \
# 0           Crohn's disease   10    6060049
# 1           Crohn's disease   16   28479196
# 2           Crohn's disease    1   67240275
# 3           Crohn's disease    2  102437989
# 4           Crohn's disease    5  159360377
# ...                     ...  ...        ...
# 185719  Lung adenocarcinoma    6   31652743
# 185720  Lung adenocarcinoma   15   78601997
# 185721  Lung adenocarcinoma    5    1342599
# 185722  Lung adenocarcinoma    6   28808340
# 185723  Lung adenocarcinoma    5    1286401
#
#                            genes_reportados        genes_mapeados  \
# 0                                     IL2RA                 IL2RA
# 1         IL27 | SH2B1 | EIF3C | LAT | CD19     CLN3 | AC138894.1
# 2                                     IL23R                 IL23R
# 3       IL12RL2 | IL18R1 | IL1RL1 | IL18RAP               IL18RAP
# 4                                     IL12B            AC008691.1
# ...                                     ...                   ...
# 185719                          APOM | BAT3           APOM | APOM
# 185720                      CHRNA5 | CHRNA3                CHRNA3
# 185721                              CLPTM1L               CLPTM1L
# 185722                            TRNAA-UGC  NOP56P1 - AL662890.1
# 185723                                 TERT                  TERT
#
#         alelo_riesgo             contexto  es_intergenico frec_alelo_riesgo  \
# 0       rs12722489-C       intron_variant             0.0             0.852
# 1         rs151181-G       intron_variant             0.0             0.386
# 2       rs11209026-G     missense_variant             0.0             0.932
# 3        rs2058660-G       intron_variant             0.0             0.231
# 4        rs6556412-A       intron_variant             0.0             0.332
# ...              ...                  ...             ...               ...
# 185719   rs3117582-C       intron_variant             0.0              0.10
# 185720   rs1051730-T   synonymous_variant             0.0              0.35
# 185721     rs31489-C       intron_variant             0.0              0.59
# 185722   rs4324798-A   intergenic_variant             1.0              0.09
# 185723   rs2736100-G  3_prime_UTR_variant             0.0              0.50
#
#        p_value  OR_or_beta  conf_int_95 gen_mapeado_elegido
# 0         3E-9        1.11  [1.05-1.16]               IL2RA
# 1        2E-11        1.07  [1.03-1.12]                CLN3
# 2        1E-64        2.66  [2.36-3.00]               IL23R
# 3        2E-12        1.19  [1.14-1.26]             IL18RAP
# 4        5E-14        1.18  [1.13-1.24]                None
# ...        ...         ...          ...                 ...
# 185719   5E-12        1.22  [1.15-1.29]                APOM
# 185720   2E-51        1.31  [1.27-1.36]              CHRNA3
# 185721   2E-10        1.12  [1.09-1.16]             CLPTM1L
# 185722    2E-8        1.16  [1.09-1.24]                None
# 185723   2E-10        1.12  [1.08-1.16]                TERT
#
# [185724 rows x 13 columns]

# %% [markdown]
# ### Categorías más generales de los fenotipos

# %%
path = f"{data_dir}/gwas_catalog_trait-mappings_r2020-05-17.tsv.gz"
trait_mappings = pd.read_table(path)
trait_mappings.head()
# Out:
#                                                            Disease trait  \
# 0                                                               Clubfoot
# 1  Alcohol dependence or heroin dependence or methamphetamine dependence
# 2                                             Methamphetamine dependence
# 3                                                         Hypothyroidism
# 4                                                       Age at menopause
#
#                                                             EFO term  \
# 0  familial clubfoot with or without associated lower limb anomalies
# 1                                         methamphetamine dependence
# 2                                         methamphetamine dependence
# 3                                                     hypothyroidism
# 4                                                   age at menopause
#
#                                      EFO URI            Parent term  \
# 0  http://www.orpha.net/ORDO/Orphanet_199315          Other disease
# 1       http://www.ebi.ac.uk/efo/EFO_0004701  Neurological disorder
# 2       http://www.ebi.ac.uk/efo/EFO_0004701  Neurological disorder
# 3       http://www.ebi.ac.uk/efo/EFO_0004705          Other disease
# 4       http://www.ebi.ac.uk/efo/EFO_0004704      Other measurement
#
#                              Parent URI
# 0  http://www.ebi.ac.uk/efo/EFO_0000408
# 1  http://www.ebi.ac.uk/efo/EFO_0000618
# 2  http://www.ebi.ac.uk/efo/EFO_0000618
# 3  http://www.ebi.ac.uk/efo/EFO_0000408
# 4  http://www.ebi.ac.uk/efo/EFO_0001444

# %%
fenotipo_a_categoria = dict(zip(trait_mappings["Disease trait"], trait_mappings["Parent term"]))
fenotipo_a_EFO_URI = dict(zip(trait_mappings["Disease trait"], trait_mappings["EFO URI"]))

categorias = df_assoc.fenotipo.map(fenotipo_a_categoria)

df_assoc["EFO_URI"] = df_assoc.fenotipo.map(fenotipo_a_EFO_URI)
df_assoc.insert(0, "categoria_fenotipo", categorias)

df_assoc["es_intergenico"] = df_assoc.es_intergenico.astype(bool)

df_assoc
# Out:
#                categoria_fenotipo             fenotipo crom        pos  \
# 0       Digestive system disorder      Crohn's disease   10    6060049
# 1       Digestive system disorder      Crohn's disease   16   28479196
# 2       Digestive system disorder      Crohn's disease    1   67240275
# 3       Digestive system disorder      Crohn's disease    2  102437989
# 4       Digestive system disorder      Crohn's disease    5  159360377
# ...                           ...                  ...  ...        ...
# 185719                     Cancer  Lung adenocarcinoma    6   31652743
# 185720                     Cancer  Lung adenocarcinoma   15   78601997
# 185721                     Cancer  Lung adenocarcinoma    5    1342599
# 185722                     Cancer  Lung adenocarcinoma    6   28808340
# 185723                     Cancer  Lung adenocarcinoma    5    1286401
#
#                            genes_reportados        genes_mapeados  \
# 0                                     IL2RA                 IL2RA
# 1         IL27 | SH2B1 | EIF3C | LAT | CD19     CLN3 | AC138894.1
# 2                                     IL23R                 IL23R
# 3       IL12RL2 | IL18R1 | IL1RL1 | IL18RAP               IL18RAP
# 4                                     IL12B            AC008691.1
# ...                                     ...                   ...
# 185719                          APOM | BAT3           APOM | APOM
# 185720                      CHRNA5 | CHRNA3                CHRNA3
# 185721                              CLPTM1L               CLPTM1L
# 185722                            TRNAA-UGC  NOP56P1 - AL662890.1
# 185723                                 TERT                  TERT
#
#         alelo_riesgo             contexto  es_intergenico frec_alelo_riesgo  \
# 0       rs12722489-C       intron_variant           False             0.852
# 1         rs151181-G       intron_variant           False             0.386
# 2       rs11209026-G     missense_variant           False             0.932
# 3        rs2058660-G       intron_variant           False             0.231
# 4        rs6556412-A       intron_variant           False             0.332
# ...              ...                  ...             ...               ...
# 185719   rs3117582-C       intron_variant           False              0.10
# 185720   rs1051730-T   synonymous_variant           False              0.35
# 185721     rs31489-C       intron_variant           False              0.59
# 185722   rs4324798-A   intergenic_variant            True              0.09
# 185723   rs2736100-G  3_prime_UTR_variant           False              0.50
#
#        p_value  OR_or_beta  conf_int_95 gen_mapeado_elegido  \
# 0         3E-9        1.11  [1.05-1.16]               IL2RA
# 1        2E-11        1.07  [1.03-1.12]                CLN3
# 2        1E-64        2.66  [2.36-3.00]               IL23R
# 3        2E-12        1.19  [1.14-1.26]             IL18RAP
# 4        5E-14        1.18  [1.13-1.24]                None
# ...        ...         ...          ...                 ...
# 185719   5E-12        1.22  [1.15-1.29]                APOM
# 185720   2E-51        1.31  [1.27-1.36]              CHRNA3
# 185721   2E-10        1.12  [1.09-1.16]             CLPTM1L
# 185722    2E-8        1.16  [1.09-1.24]                None
# 185723   2E-10        1.12  [1.08-1.16]                TERT
#
#                                      EFO_URI
# 0       http://www.ebi.ac.uk/efo/EFO_0000384
# 1       http://www.ebi.ac.uk/efo/EFO_0000384
# 2       http://www.ebi.ac.uk/efo/EFO_0000384
# 3       http://www.ebi.ac.uk/efo/EFO_0000384
# 4       http://www.ebi.ac.uk/efo/EFO_0000384
# ...                                      ...
# 185719  http://www.ebi.ac.uk/efo/EFO_0000571
# 185720  http://www.ebi.ac.uk/efo/EFO_0000571
# 185721  http://www.ebi.ac.uk/efo/EFO_0000571
# 185722  http://www.ebi.ac.uk/efo/EFO_0000571
# 185723  http://www.ebi.ac.uk/efo/EFO_0000571
#
# [185724 rows x 15 columns]

# %%
path = f"{results_dir}/GwasCat_associations.r2020-05-03.parsed.csv.gz"
print(path)
df_assoc.to_csv(path, index=False)
# Out:
# results/GwasCat_associations.r2020-05-03.parsed.csv.gz

# %%
! zcat $path | head | column -s"," -t
# Out:
# gzip: stdout: Broken pipe
# categoria_fenotipo         fenotipo         crom  pos        genes_reportados                     genes_mapeados           alelo_riesgo  contexto                   es_intergenico  frec_alelo_riesgo  p_value  OR_or_beta  conf_int_95  gen_mapeado_elegido                   EFO_URI
# Digestive system disorder  Crohn's disease  10    6060049    IL2RA                                IL2RA                    rs12722489-C  intron_variant             False           0.852              3E-9     1.11        [1.05-1.16]  IL2RA                                 http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  16    28479196   IL27 | SH2B1 | EIF3C | LAT | CD19    CLN3 | AC138894.1        rs151181-G    intron_variant             False           0.386              2E-11    1.07        [1.03-1.12]  CLN3                                  http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  1     67240275   IL23R                                IL23R                    rs11209026-G  missense_variant           False           0.932              1E-64    2.66        [2.36-3.00]  IL23R                                 http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  2     102437989  IL12RL2 | IL18R1 | IL1RL1 | IL18RAP  IL18RAP                  rs2058660-G   intron_variant             False           0.231              2E-12    1.19        [1.14-1.26]  IL18RAP                               http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  5     159360377  IL12B                                AC008691.1               rs6556412-A   intron_variant             False           0.332              5E-14    1.18        [1.13-1.24]  http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  1     7819003    VAMP3                                PER3 | Z98884.1          rs2797685-A   intron_variant             False           0.19               7E-9     1.05        [1.01-1.10]  PER3                                  http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  1     206766559  IL10 | IL19                          Y_RNA - IL10             rs3024505-T   intergenic_variant         True            0.157              2E-14    1.12        [1.07-1.17]  http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  7     50264865   ZPBP | IKZF1 | FIGNL1                AC020743.2 - AC020743.3  rs1456896-T   regulatory_region_variant  True            0.69               1E-8     1.14        [1.09-1.20]  http://www.ebi.ac.uk/efo/EFO_0000384
# Digestive system disorder  Crohn's disease  21    44195140   ICOSLG                               GATD3A                   rs2838519-G   intron_variant             False           0.391              2E-14    1.18        [1.13-1.23]  GATD3A                                http://www.ebi.ac.uk/efo/EFO_0000384
